# %% [markdown]
# # Lab 12: Semantic Search with Approximate Nearest Neighbors and Text Embeddings

# %% [markdown]
# https://www.tensorflow.org/hub/tutorials/tf2_semantic_approximate_nearest_neighbors
